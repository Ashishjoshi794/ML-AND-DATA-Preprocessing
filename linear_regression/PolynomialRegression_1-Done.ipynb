# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
numbers = np.random.rand(100,1)
numbers.shape
# Out:
# (100, 1)

# %%
x = 6 * 0.87707666 - 3
x
# Out:
# 2.2624599599999993

# %%
y = 0.5 * (2.2624599599999993) ** 2 + 1.5 * (2.2624599599999993) + 2
y
# Out:
# 7.9530524753015985

# %%
X = 6 * numbers - 3
y = 0.5 * X**2 + 1.5*X + 2 + 2*(np.random.rand(100,1))
# y = 0.5*x^2 + 1.5*x + 2

# %%
print(X)
# Out:
# [[ 1.50587801]
#  [ 1.04333347]
#  [-2.1714409 ]
#  [ 0.93709115]
#  [ 1.84218303]
#  [-2.03732586]
#  [ 1.43807735]
#  [ 1.20257037]
#  [-0.16479966]
#  [-1.57921479]
#  [ 0.24827661]
#  [-2.99220962]
#  [ 0.05869324]
#  [-2.00331112]
#  [-1.75254745]
#  [ 0.61787073]
#  [ 1.23562709]
#  [ 1.31905339]
#  [-1.76842808]
#  [-0.79921153]
#  [ 2.18259764]
#  [-0.93333177]
#  [ 1.83976767]
#  [ 1.73523357]
#  [ 2.61820814]
#  [-1.0399888 ]
#  [ 1.21497005]
#  [-2.11900878]
#  [ 1.6984601 ]
#  [-2.36334013]
#  [ 0.65945185]
#  [-2.43484847]
#  [-0.6002682 ]
#  [-2.12431369]
#  [ 1.23166738]
#  [ 2.28550024]
#  [-0.1171028 ]
#  [-2.11441897]
#  [-2.3868706 ]
#  [-1.92800691]
#  [ 2.12874036]
#  [ 1.24769623]
#  [-1.3889321 ]
#  [-1.60364003]
#  [ 2.39087929]
#  [-0.18089225]
#  [-2.17115262]
#  [-1.15369187]
#  [-1.45638445]
#  [-2.01537744]
#  [ 2.0497726 ]
#  [-0.19416867]
#  [-0.14003704]
#  [-0.37215424]
#  [-0.91042265]
#  [ 1.96788928]
#  [-0.84395092]
#  [ 0.15785759]
# ...

# %%
y
# Out:
# array([[ 6.74376903],
#        [ 5.0386928 ],
#        [ 1.11365431],
#        [ 5.23490871],
#        [ 7.48221169],
#        [ 1.24322558],
#        [ 7.12306493],
#        [ 4.53787622],
#        [ 1.93385225],
#        [ 1.18596319],
#        [ 3.90340763],
#        [ 3.83873957],
#        [ 2.24579279],
#        [ 1.86726348],
#        [ 1.1426016 ],
#        [ 3.31538271],
#        [ 5.7392759 ],
#        [ 5.28451906],
#        [ 2.75507259],
#        [ 1.66438614],
#        [ 8.77105661],
#        [ 1.19774408],
#        [ 8.41097929],
#        [ 6.91538679],
#        [ 9.58922677],
#        [ 2.78202459],
#        [ 6.45993721],
#        [ 1.88892617],
#        [ 6.15259584],
#        [ 1.92926109],
#        [ 3.97252563],
#        [ 2.918772  ],
#        [ 1.42111541],
#        [ 2.29420272],
#        [ 5.68906785],
#        [ 8.39251189],
#        [ 2.22172205],
#        [ 1.22698309],
#        [ 3.18132287],
#        [ 1.3838409 ],
#        [ 8.50918691],
# ...

# %%
plt.scatter(X, y)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100, 1))

# %%
# quadratic equation used - y = 0.5 * X**2 + 1.5*X + 2 + outliers
plt.scatter(X, y, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
X
# Out:
# array([[ 1.50587801],
#        [ 1.04333347],
#        [-2.1714409 ],
#        [ 0.93709115],
#        [ 1.84218303],
#        [-2.03732586],
#        [ 1.43807735],
#        [ 1.20257037],
#        [-0.16479966],
#        [-1.57921479],
#        [ 0.24827661],
#        [-2.99220962],
#        [ 0.05869324],
#        [-2.00331112],
#        [-1.75254745],
#        [ 0.61787073],
#        [ 1.23562709],
#        [ 1.31905339],
#        [-1.76842808],
#        [-0.79921153],
#        [ 2.18259764],
#        [-0.93333177],
#        [ 1.83976767],
#        [ 1.73523357],
#        [ 2.61820814],
#        [-1.0399888 ],
#        [ 1.21497005],
#        [-2.11900878],
#        [ 1.6984601 ],
#        [-2.36334013],
#        [ 0.65945185],
#        [-2.43484847],
#        [-0.6002682 ],
#        [-2.12431369],
#        [ 1.23166738],
#        [ 2.28550024],
#        [-0.1171028 ],
#        [-2.11441897],
#        [-2.3868706 ],
#        [-1.92800691],
#        [ 2.12874036],
# ...

# %%
y
# Out:
# array([[ 6.74376903],
#        [ 5.0386928 ],
#        [ 1.11365431],
#        [ 5.23490871],
#        [ 7.48221169],
#        [ 1.24322558],
#        [ 7.12306493],
#        [ 4.53787622],
#        [ 1.93385225],
#        [ 1.18596319],
#        [ 3.90340763],
#        [ 3.83873957],
#        [ 2.24579279],
#        [ 1.86726348],
#        [ 1.1426016 ],
#        [ 3.31538271],
#        [ 5.7392759 ],
#        [ 5.28451906],
#        [ 2.75507259],
#        [ 1.66438614],
#        [ 8.77105661],
#        [ 1.19774408],
#        [ 8.41097929],
#        [ 6.91538679],
#        [ 9.58922677],
#        [ 2.78202459],
#        [ 6.45993721],
#        [ 1.88892617],
#        [ 6.15259584],
#        [ 1.92926109],
#        [ 3.97252563],
#        [ 2.918772  ],
#        [ 1.42111541],
#        [ 2.29420272],
#        [ 5.68906785],
#        [ 8.39251189],
#        [ 2.22172205],
#        [ 1.22698309],
#        [ 3.18132287],
#        [ 1.3838409 ],
#        [ 8.50918691],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train
# Out:
# array([[-2.99220962],
#        [-1.15369187],
#        [-2.62496657],
#        [ 1.6984601 ],
#        [ 2.50964279],
#        [-2.03732586],
#        [-0.17229688],
#        [ 0.26778121],
#        [ 2.28550024],
#        [ 1.23562709],
#        [-2.01537744],
#        [ 1.23166738],
#        [ 1.20257037],
#        [-1.15559191],
#        [-2.11900878],
#        [-0.79921153],
#        [ 2.04260097],
#        [-1.0399888 ],
#        [-0.72039443],
#        [-2.00331112],
#        [ 2.61820814],
#        [ 0.93709115],
#        [ 1.31905339],
#        [-2.3868706 ],
#        [-0.16479966],
#        [ 2.75894856],
#        [ 1.43807735],
#        [ 1.32593943],
#        [-0.1171028 ],
#        [ 1.11120241],
#        [-0.84395092],
#        [ 2.75096222],
#        [-0.91042265],
#        [-1.60364003],
#        [ 2.0497726 ],
#        [ 0.11164132],
#        [-2.17115262],
#        [-0.61112738],
#        [-1.0821164 ],
#        [ 2.5879049 ],
#        [ 1.97973363],
# ...

# %%
## Simple Linear Regression
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg
# Out:
# LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)
y_pred
# Out:
# array([[7.40417714],
#        [3.82712102],
#        [7.75509246],
#        [4.13298893],
#        [8.24578944],
#        [1.33898724],
#        [7.36444671],
#        [2.39381775],
#        [4.81931969],
#        [6.83048732],
#        [1.59418715],
#        [5.47687488],
#        [7.88666154],
#        [1.02505164],
#        [3.69512152],
#        [7.36830939],
#        [8.541303  ],
#        [8.16963298],
#        [4.51613623],
#        [0.52844159],
#        [7.56933996],
#        [1.79284062],
#        [6.36526465],
#        [2.20108058],
#        [4.28805048],
#        [5.41037798],
#        [7.82657447],
#        [8.49532437],
#        [1.89677877],
#        [4.06426963]])

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print('R2 score for Linear Regression:', score)
# Out:
# R2 score for Linear Regression: 0.8178620154372869

# %%
## Visualize this model
plt.plot(X_train, lin_reg.predict(X_train), color = 'r')
plt.scatter(X_train, y_train, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
## Visualize this model
plt.plot(X_test, lin_reg.predict(X_test), color = 'r')
plt.scatter(X_test, y_test, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
# Out:
# Text(0, 0.5, 'y dataset')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Applying Polynomial Transformation
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_train_poly.shape
# Out:
# (70, 2)

# %%
dftrain = pd.DataFrame(X_train_poly, columns=["X1", "X2"])
dftrain
# Out:
#           X1        X2
# 0  -2.992210  8.953318
# 1  -1.153692  1.331005
# 2  -2.624967  6.890450
# 3   1.698460  2.884767
# 4   2.509643  6.298307
# ..       ...       ...
# 65  2.846510  8.102617
# 66 -2.341878  5.484395
# 67 -1.752547  3.071423
# 68  1.733556  3.005216
# 69 -0.194169  0.037701
#
# [70 rows x 2 columns]

# %%
dftrain = dftrain.drop(columns=["X0"])
dftrain

# %%
dftest = pd.DataFrame(X_test_poly, columns=["X1", "X2"])
dftest
# Out:
#           X1        X2
# 0   1.864611  3.476776
# 1  -0.372154  0.138499
# 2   2.084042  4.343231
# 3  -0.180892  0.032722
# 4   2.390879  5.716304
# 5  -1.928007  3.717211
# 6   1.839768  3.384745
# 7  -1.268412  1.608868
# 8   0.248277  0.061641
# 9   1.505878  2.267669
# 10 -1.768428  3.127338
# 11  0.659452  0.434877
# 12  2.166313  4.692914
# 13 -2.124314  4.512709
# 14 -0.454695  0.206747
# 15  1.842183  3.393638
# 16  2.575667  6.634058
# 17  2.343258  5.490858
# 18  0.058693  0.003445
# 19 -2.434848  5.928487
# 20  1.967889  3.872588
# 21 -1.644208  2.703421
# 22  1.214970  1.476152
# 23 -1.388932  1.929132
# 24 -0.083931  0.007044
# 25  0.617871  0.381764
# 26  2.128740  4.531536
# 27  2.546916  6.486780
# 28 -1.579215  2.493919
# 29 -0.223863  0.050115

# %%
dftest = dftest.drop(columns=["X0"])
dftest

# %%
X_test_poly
# Out:
# array([[ 1.86461147e+00,  3.47677593e+00],
#        [-3.72154239e-01,  1.38498777e-01],
#        [ 2.08404201e+00,  4.34323109e+00],
#        [-1.80892254e-01,  3.27220075e-02],
#        [ 2.39087929e+00,  5.71630376e+00],
#        [-1.92800691e+00,  3.71721064e+00],
#        [ 1.83976767e+00,  3.38474508e+00],
#        [-1.26841180e+00,  1.60886849e+00],
#        [ 2.48276610e-01,  6.16412750e-02],
#        [ 1.50587801e+00,  2.26766857e+00],
#        [-1.76842808e+00,  3.12733787e+00],
#        [ 6.59451846e-01,  4.34876737e-01],
#        [ 2.16631335e+00,  4.69291352e+00],
#        [-2.12431369e+00,  4.51270866e+00],
#        [-4.54694724e-01,  2.06747292e-01],
#        [ 1.84218303e+00,  3.39363833e+00],
#        [ 2.57566660e+00,  6.63405845e+00],
#        [ 2.34325796e+00,  5.49085787e+00],
#        [ 5.86932357e-02,  3.44489592e-03],
#        [-2.43484847e+00,  5.92848707e+00],
#        [ 1.96788928e+00,  3.87258822e+00],
#        [-1.64420826e+00,  2.70342081e+00],
# ...

# %%
from sklearn.metrics import r2_score
lin_reg2 = LinearRegression()
lin_reg2.fit(X_train_poly, y_train)
y_pred = lin_reg2.predict(X_test_poly)
score = r2_score(y_test, y_pred)
print('R2 score for Polynomial Regression:', score)
# Out:
# R2 score for Polynomial Regression: 0.9595859413498744

# %%
from sklearn.metrics import r2_score
lin_reg2 = LinearRegression()
lin_reg2.fit(dftrain, y_train)
y_pred = lin_reg2.predict(dftest)
score = r2_score(y_test, y_pred)
print('R2 score for Polynomial Regression:', score)
# Out:
# R2 score for Polynomial Regression: 0.9595859413498744

# %%
print('Coefficients:', lin_reg2.coef_)
# Out:
# Coefficients: [[1.51206741 0.49263977]]

# %%
print('Intercept:', lin_reg2.intercept_)
# Out:
# Intercept: [2.94971233]

# %%
plt.plot(X_train, lin_reg2.predict(X_train_poly), 'r.')
plt.scatter(X_train, y_train, color = 'g')
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection="3d")
ax.scatter(dftrain['X1'], dftrain['X2'], y_train, color='green')
ax.plot(dftrain['X1'], dftrain['X2'], lin_reg2.predict(dftrain), color="red", linestyle='', marker='o')
plt.show()

# %%
X_train_poly.shape
# Out:
# (70, 2)

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection="3d")
ax.scatter(dftrain['X1'], dftrain['X2'], y_train, color='green')
ax.plot(dftrain['X1'], dftrain['X2'], lin_reg2.predict(dftrain), color="blue", linestyle='', marker='o')
plt.show()

# %%
plt.plot(dftrain, lin_reg2.predict(dftrain), c='blue')
plt.scatter(dftrain["X1"], y_train, c='green')

# %%
# Prediction of new data set
X_new = np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
X_new_poly
# Out:
# array([[-3.00000000e+00,  9.00000000e+00],
#        [-2.96984925e+00,  8.82000455e+00],
#        [-2.93969849e+00,  8.64182723e+00],
#        [-2.90954774e+00,  8.46546804e+00],
#        [-2.87939698e+00,  8.29092700e+00],
#        [-2.84924623e+00,  8.11820409e+00],
#        [-2.81909548e+00,  7.94729931e+00],
#        [-2.78894472e+00,  7.77821267e+00],
#        [-2.75879397e+00,  7.61094417e+00],
#        [-2.72864322e+00,  7.44549380e+00],
#        [-2.69849246e+00,  7.28186157e+00],
#        [-2.66834171e+00,  7.12004747e+00],
#        [-2.63819095e+00,  6.96005151e+00],
#        [-2.60804020e+00,  6.80187369e+00],
#        [-2.57788945e+00,  6.64551400e+00],
#        [-2.54773869e+00,  6.49097245e+00],
#        [-2.51758794e+00,  6.33824903e+00],
#        [-2.48743719e+00,  6.18734375e+00],
#        [-2.45728643e+00,  6.03825661e+00],
#        [-2.42713568e+00,  5.89098760e+00],
#        [-2.39698492e+00,  5.74553673e+00],
#        [-2.36683417e+00,  5.60190399e+00],
# ...

# %%
y_new = lin_reg2.predict(X_new_poly)
plt.plot(X_new, y_new, color = 'r', label = 'Predictions')
plt.plot(X_train, y_train, '.k', label = 'Training data')
plt.plot(X_test, y_test, 'y.', label = 'Test data')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.legend()
plt.show()
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %% [markdown]
# Pipelining

# %% [markdown]
# A pipeline is a sequence of data processing and model training steps arranged in order, so you can automate and reproduce the entire ML workflow easily.
#
# Pipelining means connecting multiple ML steps into one continuous process

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    poly_features = PolynomialFeatures(degree = degree)
    lin_reg = LinearRegression()
    poly_regression = Pipeline([
        ('poly_features', poly_features),
        ('lin_reg', lin_reg)
    ])
    poly_regression.fit(X_train, y_train)
    y_pred_new = poly_regression.predict(X_new)
    # Plotting prediction line
    plt.plot(X_new, y_pred_new, label = 'Predictions', color = 'r')
    plt.plot(X_train, y_train, 'g.', label = 'Training data')
    # plt.plot(X_test, y_test, 'b.', label = 'Test data')
    plt.legend(loc = "upper left")
    plt.xlabel('X dataset')
    plt.ylabel('y dataset')
    plt.show()

# %%
poly_regression(10)
